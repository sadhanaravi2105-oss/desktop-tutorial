# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heartdisease.csv')
df.head()
# Out:
#    age  Gender  Family  diet  Lifestyle  cholestrol  heartdisease
# 0    0       0       0     1          3           1             0
# 1    0       0       1     1          3           1             1
# 2    1       0       0     0          0           2             1
# 3    4       0       1     1          1           2             0
# 4    3       1       1     0          0           0             0

# %%
df.shape
# Out:
# (19, 7)

# %%
df.isnull().sum()
# Out:
# age             0
# Gender          0
# Family          0
# diet            0
# Lifestyle       0
# cholestrol      0
# heartdisease    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           19 non-null     int64
#  1   Gender        19 non-null     int64
#  2   Family        19 non-null     int64
#  3   diet          19 non-null     int64
#  4   Lifestyle     19 non-null     int64
#  5   cholestrol    19 non-null     int64
#  6   heartdisease  19 non-null     int64
# dtypes: int64(7)
# memory usage: 1.2 KB

# %%
df.describe()
# Out:
#              age     Gender     Family       diet  Lifestyle  cholestrol  \
# count  19.000000  19.000000  19.000000  19.000000  19.000000   19.000000
# mean    1.684211   0.421053   0.526316   0.526316   1.473684    1.105263
# std     1.454977   0.507257   0.512989   0.512989   1.172292    0.809303
# min     0.000000   0.000000   0.000000   0.000000   0.000000    0.000000
# 25%     0.500000   0.000000   0.000000   0.000000   0.500000    0.500000
# 50%     1.000000   0.000000   1.000000   1.000000   1.000000    1.000000
# 75%     3.000000   1.000000   1.000000   1.000000   2.500000    2.000000
# max     4.000000   1.000000   1.000000   1.000000   3.000000    2.000000
#
#        heartdisease
# count     19.000000
# mean       0.473684
# std        0.512989
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
df.columns
# Out:
# Index(['age', 'Gender', 'Family', 'diet', 'Lifestyle', 'cholestrol',
#        'heartdisease'],
#       dtype='object')

# %%
# !pip install pgmpy==1.0.0 
import pgmpy 
print(pgmpy.__version__)
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pgmpy==1.0.0 in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (1.0.0)
# Requirement already satisfied: networkx in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from pgmpy==1.0.0) (3.6.1)
# Requirement already satisfied: numpy in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from pgmpy==1.0.0) (2.5.1)
# Requirement already satisfied: scipy in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from pgmpy==1.0.0) (1.18.0)
# Requirement already satisfied: scikit-learn in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from pgmpy==1.0.0) (1.9.0)
# Requirement already satisfied: pandas in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from pgmpy==1.0.0) (2.3.3)
# Requirement already satisfied: torch in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from pgmpy==1.0.0) (2.13.0)
# Requirement already satisfied: statsmodels in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from pgmpy==1.0.0) (0.14.6)
# Requirement already satisfied: tqdm in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from pgmpy==1.0.0) (4.70.0)
# Requirement already satisfied: joblib in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from pgmpy==1.0.0) (1.5.3)
# Requirement already satisfied: opt-einsum in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from pgmpy==1.0.0) (3.4.0)
# Requirement already satisfied: pyro-ppl in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from pgmpy==1.0.0) (1.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from pandas->pgmpy==1.0.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from pandas->pgmpy==1.0.0) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from pandas->pgmpy==1.0.0) (2026.3)
# Requirement already satisfied: pyro-api>=0.1.1 in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from pyro-ppl->pgmpy==1.0.0) (0.1.2)
# Requirement already satisfied: filelock in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from torch->pgmpy==1.0.0) (3.32.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from torch->pgmpy==1.0.0) (4.16.0)
# Requirement already satisfied: setuptools>=77.0.3 in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from torch->pgmpy==1.0.0) (83.0.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from torch->pgmpy==1.0.0) (1.14.0)
# Requirement already satisfied: jinja2 in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from torch->pgmpy==1.0.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from torch->pgmpy==1.0.0) (2026.7.0)
# Requirement already satisfied: colorama in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from tqdm->pgmpy==1.0.0) (0.4.6)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->pgmpy==1.0.0) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->pgmpy==1.0.0) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from statsmodels->pgmpy==1.0.0) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from statsmodels->pgmpy==1.0.0) (26.2)
# Requirement already satisfied: six>=1.5 in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->pgmpy==1.0.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch->pgmpy==1.0.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\l.thamizharasi\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch->pgmpy==1.0.0) (3.0.3)
# 1.0.0

# %%
from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.estimators import MaximumLikelihoodEstimator
model = DiscreteBayesianNetwork([
    ('age', 'heartdisease'),
    ('Gender', 'heartdisease'),
    ('Family', 'heartdisease'),
    ('diet', 'heartdisease'), 
    ('Lifestyle', 'heartdisease'),
    ('cholestrol', 'heartdisease')]) 
mle = MaximumLikelihoodEstimator(model, df) 
cpds = mle.get_parameters() 
model.add_cpds(*cpds)
print(model.get_cpds('heartdisease'))
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'age': 'N', 'Gender': 'N', 'Family': 'N', 'diet': 'N', 'Lifestyle': 'N', 'cholestrol': 'N', 'heartdisease': 'N'}
# +-----------------+---------------+---------------+-----+---------------+---------------+---------------+
# | Family          | Family(0)     | Family(0)     | ... | Family(1)     | Family(1)     | Family(1)     |
# +-----------------+---------------+---------------+-----+---------------+---------------+---------------+
# | Gender          | Gender(0)     | Gender(0)     | ... | Gender(1)     | Gender(1)     | Gender(1)     |
# +-----------------+---------------+---------------+-----+---------------+---------------+---------------+
# | Lifestyle       | Lifestyle(0)  | Lifestyle(0)  | ... | Lifestyle(3)  | Lifestyle(3)  | Lifestyle(3)  |
# +-----------------+---------------+---------------+-----+---------------+---------------+---------------+
# | age             | age(0)        | age(0)        | ... | age(4)        | age(4)        | age(4)        |
# +-----------------+---------------+---------------+-----+---------------+---------------+---------------+
# | cholestrol      | cholestrol(0) | cholestrol(0) | ... | cholestrol(1) | cholestrol(2) | cholestrol(2) |
# +-----------------+---------------+---------------+-----+---------------+---------------+---------------+
# | diet            | diet(0)       | diet(1)       | ... | diet(1)       | diet(0)       | diet(1)       |
# +-----------------+---------------+---------------+-----+---------------+---------------+---------------+
# | heartdisease(0) | 0.5           | 0.5           | ... | 0.5           | 0.5           | 0.5           |
# +-----------------+---------------+---------------+-----+---------------+---------------+---------------+
# | heartdisease(1) | 0.5           | 0.5           | ... | 0.5           | 0.5           | 0.5           |
# +-----------------+---------------+---------------+-----+---------------+---------------+---------------+

# %%
print(model.get_cpds('age'))
# Out:
# +--------+----------+
# | age(0) | 0.263158 |
# +--------+----------+
# | age(1) | 0.263158 |
# +--------+----------+
# | age(2) | 0.157895 |
# +--------+----------+
# | age(3) | 0.157895 |
# +--------+----------+
# | age(4) | 0.157895 |
# +--------+----------+

# %%
print(model.get_cpds('Gender'))
# Out:
# +-----------+----------+
# | Gender(0) | 0.578947 |
# +-----------+----------+
# | Gender(1) | 0.421053 |
# +-----------+----------+

# %%
print(model.get_cpds('Family'))
# Out:
# +-----------+----------+
# | Family(0) | 0.473684 |
# +-----------+----------+
# | Family(1) | 0.526316 |
# +-----------+----------+
